# %%
import pymongo
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import json
from pymongo import MongoClient
# %matplotlib qt5

# %%
# plt.style.available

# %%
client = MongoClient('mongodb://bonnyberliner2:test123@ds143539.mlab.com:43539/heroku_l96r9wz3')
db = client.get_default_database()

# %%
collections = db.collection_names()

# %%
collections
# Out:
# ['shoes', 'users', 'votes', 'system.indexes', 'sessions']

# %%
shoes = db.shoes.find()

product_info = shoes[0]['product_info']

# json.loads (s for string) is basically JSON.parse()
ASIN = json.loads(product_info['ASIN'])[0]
# json.dumps is basically JSON.stringify()
# json.dumps(ASIN)
ASIN
# Out:
# 'B012A4EOAK'

# %%
for shoe in shoes[0:1]:
    print(shoe)
# Out:
# {'_id': ObjectId('589dd0c01871722b53b7b7de'), 'product_info': {'ItemAttributes': '[{"Binding":["Shoes"],"Brand":["Skechers"],"ClothingSize":["13 D(M) US"],"Color":["All Black"],"Department":["mens"],"EAN":["0889110607954"],"EANList":[{"EANListElement":["0889110607954"]}],"Feature":["Lace-up sneaker featuring relaxed-fit knit upper with Air Cool memory foam insole","Flexible sole"],"ItemDimensions":[{"Weight":[{"_":"300","$":{"Units":"hundredths-pounds"}}]}],"Label":["Skechers"],"ListPrice":[{"Amount":["6500"],"CurrencyCode":["USD"],"FormattedPrice":["$65.00"]}],"Manufacturer":["Skechers"],"Model":["51532"],"MPN":["51532-BBK"],"NumberOfItems":["1"],"PackageDimensions":[{"Height":[{"_":"500","$":{"Units":"hundredths-inches"}}],"Length":[{"_":"1400","$":{"Units":"hundredths-inches"}}],"Weight":[{"_":"235","$":{"Units":"hundredths-pounds"}}],"Width":[{"_":"900","$":{"Units":"hundredths-inches"}}]}],"PackageQuantity":["1"],"PartNumber":["51532-BBK"],"ProductGroup":["Shoes"],"ProductTypeNa
# ...

# %%
votes = db.votes.find()
voteArr = []
yes = []
no = []
voteDict = {}

for n, vote in enumerate(votes):
    voteDict[n] = vote
voteDF = pd.DataFrame.from_dict(voteDict, orient='index')

# %%
voteDF
# Out:
#                            _id                      user        ASIN vote  __v
# 0     5898bd652cefd500116df036                      Anon  B00NUZIFOK    y    0
# 1     5898bd662cefd500116df037                      Anon  B01GELDQX6    y    0
# 2     5898bd672cefd500116df038                      Anon  B01J2QN7RU    n    0
# 3     5898bd6c2cefd500116df039                      Anon  B0066BE28S    y    0
# 4     5898bd6e2cefd500116df03a                      Anon  B01HM9W4Q4    n    0
# 5     5898d63a76efc600114074f1                      Anon  B01701Q6CC    n    0
# 6     5898d63c76efc600114074f2                      Anon  B00NUZIFOK    n    0
# 7     5898d63e76efc600114074f3                      Anon  B01GELDQX6    y    0
# 8     5898d64576efc600114074f4                      Anon  B01J2QN7RU    y    0
# 9     5898d85776efc600114074f5                      Anon  B01701Q6CC    y    0
# 10    5898d85876efc600114074f6                      Anon  B00NUZIFOK    n    0
# ...

# %%
shoes = db.shoes.find()
# voteArr = []
# yes = []
# no = []
shoeDict = {}
needed_cols = ['Binding','Brand','Color',
               'Department','Feature','Label',
               'ProductGroup','ProductTypeName',
               'Publisher','Studio','Title']

for n, shoe in enumerate(shoes):
    shoeDict[n] = {}
    shoe_id = shoe['_id']
    ASIN = json.loads(shoe['product_info']['ASIN'])[0]
    shoeDict[n]['_id'] = shoe_id
    shoeDict[n]['ASIN'] = ASIN
    itemAttributes = json.loads(shoe['product_info']['ItemAttributes'])[0]
#     print(itemAttributes)
    for col in needed_cols:
        try:
            shoeDict[n][col] = itemAttributes[col][0]
        except:
            shoeDict[n][col] = np.NaN
#     print(ASIN)
shoeDF = pd.DataFrame.from_dict(shoeDict, orient='index')

# %%
shoeDF
# Out:
#                         _id        ASIN  Binding              Brand  \
# 0  589dd0c01871722b53b7b7de  B012A4EOAK    Shoes           Skechers
# 1  589dd0c01871722b53b7b7d6  B01J2QN7RU  Apparel        Leader show
# 2  589dd0c01871722b53b7b7d7  B00YDI7ZBM    Shoes              ASICS
# 3  589dd0c01871722b53b7b7d8  B01GELDQX6  Apparel          JACKSHIBO
# 4  589dd0c01871722b53b7b7d9  B0066BE28S    Shoes  Polo Ralph Lauren
# 5  589dd0c01871722b53b7b7da  B01KVAKPZI  Apparel               CIOR
# 6  589dd0c01871722b53b7b7db  B01HM9W4Q4  Kitchen            Lystaii
# 7  589dd0c01871722b53b7b7dc  B0186Z5FGO    Misc.              HOMAR
# 8  589dd0c01871722b53b7b7dd  B00IYAW5WE    Shoes        New Balance
# 9  589dd0c01871722b53b7b7df  B00VKI5JV6   Sports            HICKIES
#
#                          Color    Department  \
# 0                    All Black          mens
# 1                        Black          mens
# 2  Carbon / Black / Hot Orange          mens
# ...

# %%
itemAttributes = json.loads(shoeDF['product_info'][0]['ItemAttributes'])[0]

# %%
#Take Binding, Brand, Color, Department, Feature, Label, ProductGroup, ProductTypeName, Publisher,Studio, Title

# itemAttributes
new_dict = {}
for col in needed_cols:
    new_dict[col] = itemAttributes[col][0]
    
new_dict
# Out:
# {'Binding': 'Shoes',
#  'Brand': 'Skechers',
#  'Color': 'All Black',
#  'Department': 'mens',
#  'Feature': 'Lace-up sneaker featuring relaxed-fit knit upper with Air Cool memory foam insole',
#  'Label': 'Skechers',
#  'ProductGroup': 'Shoes',
#  'ProductTypeName': 'SHOES',
#  'Publisher': 'Skechers',
#  'Studio': 'Skechers',
#  'Title': "Skechers Sport Men's Equalizer 2.0 On Track Lace Up Sneaker All Black, 13 M US"}

# %%
itemAttributeKeys = list(itemAttributes.keys())
itemAttributeKeys.append('ASIN')

# %%
itemAttributeKeys
# Out:
# ['Binding',
#  'Brand',
#  'ClothingSize',
#  'Color',
#  'Department',
#  'EAN',
#  'EANList',
#  'Feature',
#  'ItemDimensions',
#  'Label',
#  'ListPrice',
#  'Manufacturer',
#  'Model',
#  'MPN',
#  'NumberOfItems',
#  'PackageDimensions',
#  'PackageQuantity',
#  'PartNumber',
#  'ProductGroup',
#  'ProductTypeName',
#  'Publisher',
#  'Size',
#  'Studio',
#  'Title',
#  'UPC',
#  'UPCList',
#  'ASIN']

# %%
pd.DataFrame(columns=itemAttributeKeys)
# Out:
# Empty DataFrame
# Columns: [Binding, Brand, ClothingSize, Color, Department, EAN, EANList, Feature, ItemDimensions, Label, ListPrice, Manufacturer, Model, MPN, NumberOfItems, PackageDimensions, PackageQuantity, PartNumber, ProductGroup, ProductTypeName, Publisher, Size, Studio, Title, UPC, UPCList, ASIN]
# Index: []
#
# [0 rows x 27 columns]

# %%
for vote in votes:
    print(vote)

# %%
result_dict = {}

for group in voting_stats.groups:
    if group[0] not in list(result_dict.keys()):
        result_dict[group[0]] = {}
        
    result_dict[group[0]][group[1]] = len(voting_stats.get_group(group))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-42759249a64f> in <module>()
#       1 result_dict = {}
#       2
# ----> 3 for group in voting_stats.groups:
#       4     if group[0] not in list(result_dict.keys()):
#       5         result_dict[group[0]] = {}
#
# NameError: name 'voting_stats' is not defined

# %%
#Get all Product Like/Dislike Comparison
likeDF = pd.DataFrame.from_dict(result_dict, orient='index')
ind = np.arange(len(likeDF))
width = 0.35

fig, ax = plt.subplots()

likes = ax.bar(ind, likeDF.y, width, color='g')
dislikes = ax.bar(ind + width, likeDF.n, width, color='r')
ax.set_xticks(ind + width)
ax.set_xticklabels(list(likeDF.index.values), {'fontsize':10})

ax.set_xlabel('Product ASIN')
ax.set_ylabel('Counts')
ax.legend(['Likes','Dislikes'])

# %%
user_stats = voteDF.groupby(['user', 'ASIN','vote'])
voting_stats = voteDF.groupby(['ASIN','vote'])

# %%
user_dict = {}

for group in user_stats.groups:
#     print(group)
    if group[0] not in list(user_dict.keys()):
        user_dict[group[0]] = {}
    
    if group[1] not in list(user_dict[group[0]].keys()):
        user_dict[group[0]][group[1]] = {}
    
    user_dict[group[0]][group[1]][group[2]] = len(user_stats.get_group(group))
#     if group[0] not in list(user_dict.keys()):
#         user_dict[group[0]] = {}
        
#     user_dict[group[0]][group[1]] = len(voting_stats.get_group(group))
userDF = pd.DataFrame.from_dict(user_dict)

# %%
userDF
# Out:
#            5897f016b0bc7d0011134eef 5897f3c8b0bc7d0011134f4c  \
# B0000AFSXL                      NaN                      NaN
# B0066BE28S                      NaN         {'n': 3, 'y': 3}
# B00IYAW5WE                      NaN         {'n': 2, 'y': 1}
# B00NUY5WHY                      NaN                      NaN
# B00NUZIFOK                 {'y': 2}                      NaN
# B00VKI5JV6                      NaN         {'n': 1, 'y': 2}
# B00YDI7ZBM                      NaN         {'n': 4, 'y': 4}
# B012A4EOAK                      NaN         {'n': 2, 'y': 6}
# B01701Q6CC                 {'y': 2}                      NaN
# B0186Z5FGO                      NaN         {'n': 1, 'y': 3}
# B01GELDQX6                      NaN         {'n': 3, 'y': 3}
# B01HM9W4Q4                      NaN         {'n': 2, 'y': 2}
# B01J2QN7RU                      NaN         {'n': 3, 'y': 5}
# B01KVAKPZI                      NaN         {'n': 1, 'y': 4}
#
# ...

# %%
#Get Product Like/Dislike Comparison for each User

import math


fig, ax = plt.subplots()

squStr = math.ceil(len(userDF.keys())**(0.5))
plotSqr = int(str(squStr)*2)*10 + 1

for n, key in enumerate(userDF.keys()):
    ax2 = fig.add_subplot(plotSqr+n)
    ax2.set_title(key)
    print(key)
    tmp = userDF[key].dropna()
    
    for j, ASIN in enumerate(tmp):
        
        if 'y' not in ASIN:
            yy = 0
        else:
            yy = ASIN['y']
            
        if 'n' not in ASIN:
            yn = 0
        else:
            yn = ASIN['n']
        
        ax2.bar(j, yy, width=0.35, color='g')
        ax2.bar(j+0.35, -yn, width=0.35, color='r')
        
    ax2.set_xticks(np.arange(len(tmp))+0.35)
    ax2.set_xticklabels(list(tmp.index.values), {'fontsize':7})
ax.set_xticklabels([])
ax.set_yticklabels([])
fig.tight_layout()

# %%
fig, ax = plt.subplots()
x = [1,3,4]
y = [1,4,5]
axList = []
for n,i in enumerate(ax):
#     print(i)
    for m, j in enumerate(ax[n]):
#         print(ax[n][m])
        axList.append(ax[n][m])
#         axList.append(ax[i][j])
# ax[0,1].plot(x,y)
len(axList)
